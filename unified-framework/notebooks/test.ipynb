# %%
"""
Robust Test for DiscreetZetaShift Approximation

- Compares the approximation gamma_n ≈ 2 * pi * n / log(n) to the first 94 actual zeta zeros
- Computes absolute/relative errors and Pearson correlation
- Optionally plots results for visual analysis

Run: python test_discreetzetashift.py
"""

import math
import sys

try:
    import matplotlib.pyplot as plt
    has_plot = True
except ImportError:
    has_plot = False

try:
    from scipy.stats import pearsonr
    has_scipy = True
except ImportError:
    has_scipy = False

# First 94 imaginary parts of non-trivial zeta zeros (from standard tables)
zeta_zeros = [
    14.1347251417, 21.0220396388, 25.0108575801, 30.4248761259, 32.9350615877, 37.5861781588,
    40.9187190121, 43.3270732809, 48.0051508812, 49.7738324777, 52.9703214777, 56.4462476971,
    59.3470440026, 60.8317785246, 65.1125440481, 67.0798105295, 69.5464017112, 72.0671576745,
    75.7046906991, 77.1448400689, 79.3373750202, 82.9103808541, 84.7354929805, 87.4252746131,
    88.8091112076, 92.4918992706, 94.6513440405, 95.8706342282, 98.8311942182, 101.3178510057,
    103.7255380405, 105.4466230523, 107.1686111843, 111.0295355432, 111.8746591770, 114.3202209155,
    116.2266803209, 118.7907828660, 121.3701250024, 122.9468292936, 124.2568185543, 127.5166838796,
    129.5787042000, 131.0876885309, 133.4977372030, 134.7565097534, 138.1160420545, 139.7362089521,
    141.1237074040, 143.1118458076, 146.0009824868, 147.4227653426, 150.0535204208, 150.9252576122,
    153.0246938112, 156.1129092942, 157.5975918176, 158.8499881714, 161.1889641376, 163.0307096872,
    165.5370691879, 167.1844399782, 169.0945154156, 169.9119764794, 173.4115365196, 174.7541915234,
    176.4414342977, 178.3774077761, 179.9164840203, 182.2070784844, 184.8744678484, 185.5987836777,
    187.2289225835, 189.4161586560, 192.0266563607, 193.0797266038, 195.2653966795, 196.8764818410,
    198.0153096763, 201.2647519437, 202.4935945141, 204.1896718031, 205.3946972022, 207.9062588878,
    209.5765097169, 211.6908625954, 213.3479193597, 214.5470447835, 216.1695385083, 219.0675963490,
    220.7149188393, 221.4307055547, 224.0070002546, 224.9833246696
]

def approx_gamma_n(n):
    if n <= 1:
        return 0.0
    return 2 * math.pi * n / math.log(n)

def main():
    N = len(zeta_zeros)
    approx = [approx_gamma_n(n) for n in range(1, N + 1)]
    abs_errors = [abs(approx[i] - zeta_zeros[i]) for i in range(N)]
    rel_errors = [abs_errors[i] / zeta_zeros[i] for i in range(N)]

    print(f"{'n':>3} {'Actual':>16} {'Approx':>16} {'Abs.Error':>12} {'Rel.Error':>10}")
    for i in range(N):
        print(f"{i+1:3d} {zeta_zeros[i]:16.10f} {approx[i]:16.10f} {abs_errors[i]:12.6f} {rel_errors[i]:10.6f}")

    print("\nSummary:")
    print(f"Mean absolute error: {sum(abs_errors)/N:.6f}")
    print(f"Mean relative error: {sum(rel_errors)/N:.6f}")

    if has_scipy:
        r, p = pearsonr(approx, zeta_zeros)
        print(f"Pearson r: {r:.6f} (p-value: {p:.2e})")
    else:
        print("scipy not installed: skipping Pearson correlation.")

    if has_plot:
        plt.figure(figsize=(10,6))
        plt.plot(range(1,N+1), zeta_zeros, label="Actual zeros")
        plt.plot(range(1,N+1), approx, '--', label="DiscreetZetaShift approx")
        plt.xlabel("n")
        plt.ylabel("Imaginary part of zeta zero")
        plt.legend()
        plt.title("Actual vs. DiscreetZetaShift Approximation")
        plt.show()
    else:
        print("matplotlib not installed: skipping plot.")

if __name__ == "__main__":
    main()
